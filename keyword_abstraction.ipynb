# %%
import numpy as np
import torch
from sentence_transformers import SentenceTransformer, util
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 2
#       1 import numpy as np
# ----> 2 import torch
#       3 from sentence_transformers import SentenceTransformer, util
#
# File ~\AppData\Roaming\Python\Python314\site-packages\torch\__init__.py:280
#     276                     raise err
#     278         kernel32.SetErrorMode(prev_error_mode)
# --> 280     _load_dll_libraries()
#     281     del _load_dll_libraries
#     284 def _get_cuda_dep_paths(path: str, lib_folder: str, lib_name: str) -> list[str]:
#     285     # Libraries can either be in
#     286     # path/nvidia/lib_folder/lib or
#     287     # path/nvidia/cuXX/lib (since CUDA 13.0) or
#     288     # path/lib_folder/lib
#
# File ~\AppData\Roaming\Python\Python314\site-packages\torch\__init__.py:263, in _load_dll_libraries()
#     259     err = ctypes.WinError(last_error)
#     260     err.strerror += (
#     261         f' Error loading "{dll}" or one of its dependencies.'
#     262     )
# --> 263     raise err
#     264 elif res is not None:
#     265     is_loaded = True
#
# OSError: [WinError 1114] A dynamic link library (DLL) initialization routine failed. Error loading "C:\Users\bablu\AppData\Roaming\Python\Python314\site-packages\torch\lib\c10.dll" or one of its dependencies.

# %%
print(torch.cuda.is_available())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(torch.cuda.is_available())
#
# NameError: name 'torch' is not defined

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
sentences = ["I love playing cricket", "I am fine.","Football is my favourite sport UFA"]

embeddings = model.encode(sentences)

print("Sentence embedding shape:", embeddings.shape)
# Out:
# Sentence embedding shape: (3, 384)

# %%
similarity_score = util.cos_sim(embeddings[0],embedding[1])
# similarity_score
print(f"Cosine Similarity: {similarity_score.item():.4f}")
# Out:
# Cosine Similarity: 0.1219
