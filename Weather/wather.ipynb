# %%
import pandas as pd

# %%
df = pd.read_csv("weather.csv")
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# ## 1) Find all the unique 'Wind Speed' values in the data.

# %%
df["Wind Speed_km/h"].nunique()
# Out:
# 34

# %%
df["Wind Speed_km/h"].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2])

# %% [markdown]
# ## 2) Find the number of times when the 'Weather is exactly Clear'.

# %%
# df.loc[60:100]
df_clear = df[df["Weather"] == "Clear"]
df_clear
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %% [markdown]
# ## 3) Dew Point Temp_C - The temperature at which air becomes saturated with moisture (dew point), also measured in degrees Celsius.

# %%
saturated_air = df[df["Dew Point Temp_C"] <= 2]
saturated_air.loc[1000:1005]
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 1000  2/11/2012 16:00   -10.4             -18.3         52                6
# 1001  2/11/2012 17:00   -10.5             -17.0         59                4
# 1002  2/11/2012 18:00   -12.8             -17.9         66                4
# 1003  2/11/2012 19:00   -14.0             -21.2         54                7
# 1004  2/11/2012 20:00   -14.4             -19.9         63                9
# 1005  2/11/2012 21:00   -13.9             -18.6         68                7
#
#       Visibility_km  Press_kPa       Weather
# 1000           48.3     100.70  Mainly Clear
# 1001           25.0     100.68  Mainly Clear
# 1002           25.0     100.72         Clear
# 1003           25.0     100.74         Clear
# 1004           25.0     100.73         Clear
# 1005           25.0     100.71         Clear

# %% [markdown]
# ## 3) Find the number of times when the 'Wind Speed was exactly 4 km/h'.

# %%
df[df["Wind Speed_km/h"] == 4 ]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 96       1/5/2012 0:00    -8.8             -11.7         79                4
# 101      1/5/2012 5:00    -7.0              -9.5         82                4
# 146      1/7/2012 2:00    -8.1             -11.1         79                4
# ...                ...     ...               ...        ...              ...
# 8768   12/31/2012 8:00    -8.6             -10.3         87                4
# 8769   12/31/2012 9:00    -8.1              -9.6         89                4
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
# 8772  12/31/2012 12:00    -5.8              -7.5         88                4
# 8773  12/31/2012 13:00    -4.6              -6.6         86                4
#
#       Visibility_km  Press_kPa       Weather
# ...

# %%
df.loc[140:150]
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 140  1/6/2012 20:00   -10.2             -13.0         80               11
# 141  1/6/2012 21:00    -9.5             -12.5         79                9
# 142  1/6/2012 22:00    -9.3             -12.2         79               11
# 143  1/6/2012 23:00    -9.0             -12.0         79                7
# 144   1/7/2012 0:00    -8.7             -11.7         79                6
# 145   1/7/2012 1:00    -8.5             -11.4         80                0
# 146   1/7/2012 2:00    -8.1             -11.1         79                4
# 147   1/7/2012 3:00    -7.8             -10.8         79                4
# 148   1/7/2012 4:00    -7.5             -10.5         79                6
# 149   1/7/2012 5:00    -6.9              -9.7         80                4
# 150   1/7/2012 6:00    -6.7              -9.5         80                7
#
#      Visibility_km  Press_kPa Weather
# 140           25.0     100.15  Cloudy
# ...

# %% [markdown]
# ## 4) Find out all the Null Values in the data.

# %%
df.isnull().sum()
# Out:
# Date/Time            0
# Temp_C               0
# Dew Point Temp_C     0
# Rel Hum_%            0
# Wind Speed_km/h      0
# Visibility_km        0
# Press_kPa            0
# Weather Condition    0
# dtype: int64

# %% [markdown]
# ## 5) Rename the column name 'Weather' of the dataframe to 'Weather Condition'.

# %%
import pandas as pd
df = pd.read_csv("weather.csv")
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
df.rename(columns={'Weather': 'Weather Condition'}, inplace=True)
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# ## 6) What is the mean 'Visibility' ?

# %%
df["Visibility_km"].mean()
# Out:
# np.float64(27.664446721311474)

# %% [markdown]
# ## 7) Find all instances when 'Snow' was recorded.

# %%
df[df["Weather Condition"] == "Snow"]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 55       1/3/2012 7:00   -14.0             -19.5         63               19
# 84      1/4/2012 12:00   -13.7             -21.7         51               11
# 86      1/4/2012 14:00   -11.3             -19.0         53                7
# 87      1/4/2012 15:00   -10.2             -16.3         61               11
# 88      1/4/2012 16:00    -9.4             -15.5         61               13
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# ## 8) Find all instances when 'Wind Speed is above 24' and 'Visibility is 25'.

# %%
df.loc[(df["Wind Speed_km/h"] > 24) & (df["Visibility_km"] == 25)].value_counts()
# Out:
# Date/Time        Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  Visibility_km  Press_kPa  Weather Condition
# 1/1/2012 23:00    5.3     2.0              79         30               25.0           99.31      Cloudy               1
# 2/26/2012 4:00   -10.8   -15.3             69         30               25.0           101.60     Mostly Cloudy        1
# 2/5/2012 23:00   -1.5    -5.7              73         30               25.0           100.93     Cloudy               1
# 2/5/2012 22:00   -2.1    -6.7              71         28               25.0           101.06     Cloudy               1
# 2/5/2012 21:00   -2.5    -7.7              67         26               25.0           101.18     Cloudy               1
#                                                                                                                      ..
# 10/30/2012 5:00   13.7    10.5             81         37               25.0           99.32      Mainly Clear         1
# ...

# %% [markdown]
# ## 9) What is the Mean value of each column against each 'Weather Condition ?

# %%
df.groupby('Weather Condition').agg('mean', numeric_only=True)
# Out:
#                                             Temp_C  Dew Point Temp_C  \
# Weather Condition
# Clear                                     6.825716          0.089367
# Cloudy                                    7.970544          2.375810
# Drizzle                                   7.353659          5.504878
# Drizzle,Fog                               8.067500          7.033750
# Drizzle,Ice Pellets,Fog                   0.400000         -0.700000
# Drizzle,Snow                              1.050000          0.150000
# Drizzle,Snow,Fog                          0.693333          0.120000
# Fog                                       4.303333          3.159333
# Freezing Drizzle                         -5.657143         -8.000000
# Freezing Drizzle,Fog                     -2.533333         -4.183333
# Freezing Drizzle,Haze                    -5.433333         -8.000000
# Freezing Drizzle,Snow                    -5.109091         -7.072727
# ...

# %% [markdown]
# ## 10) What is the Minimum & Maximum value of each column against each 'Weather Condition ?

# %%
df.groupby('Weather Condition').agg(['min', 'max'], numeric_only=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df.groupby('Weather Condition').agg(['min', 'max'], numeric_only=True)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:1432, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1429     kwargs["engine_kwargs"] = engine_kwargs
#    1431 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1432 result = op.agg()
#    1433 if not is_dict_like(func) and result is not None:
#    1434     # GH #52849
#    1435     if not self.as_index and is_list_like(func):
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\apply.py:193, in Apply.agg(self)
#     190     return self.agg_dict_like()
#     191 elif is_list_like(func):
#     192     # we require a list, but not a 'str'
# --> 193     return self.agg_list_like()
# ...

# %% [markdown]
# ## 11) Show all the Records where Weather Condition is Fog.

# %%
df[df["Weather Condition"]=="Fog"]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# 5        1/1/2012 5:00    -1.4              -3.3         87                9
# 6        1/1/2012 6:00    -1.5              -3.1         89                7
# ...                ...     ...               ...        ...              ...
# 8716   12/29/2012 4:00   -16.0             -17.2         90                6
# 8717   12/29/2012 5:00   -14.8             -15.9         91                4
# 8718   12/29/2012 6:00   -13.8             -15.3         88                4
# 8719   12/29/2012 7:00   -14.8             -16.4         88                7
# 8722  12/29/2012 10:00   -12.0             -13.3         90                7
#
# ...

# %% [markdown]
# ## 12) Find all instances when 'Weather is Clear' or 'Visibility is above 40'.

# %%
# df[(df["Weather Condition"] == "Clear") | (df["Visibility_km"] >40)]
df.loc[(df["Weather Condition"] == "Clear") | (df["Visibility_km"] >40)]

# df[(df['Weather Condition'] == 'Clear') | (df['Visibility_km'] > 40)].shape[0]


# df.loc[
#     (df["Weather Condition"] == "Clear") | (df["Visibility_km"] > 40),
#     "Weather Condition"
# ].value_counts().plot(kind="pie", autopct="%1.1f%%")
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 106     1/5/2012 10:00    -6.0             -10.0         73               17
# 107     1/5/2012 11:00    -5.6             -10.2         70               22
# 108     1/5/2012 12:00    -4.7              -9.6         69               20
# 109     1/5/2012 13:00    -4.4              -9.7         66               26
# ...                ...     ...               ...        ...              ...
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...

# %% [markdown]
# ## 13) Find all instances when :
# ## A. 'Weather is Clear' and 'Relative Humidity is greater than 50'
# ## or
# ## B. 'Visibility is above 40'

# %%
df[((df["Weather Condition"] == "Clear") & (df["Rel Hum_%"] > 50) ) | (df["Visibility_km"] > 40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 106     1/5/2012 10:00    -6.0             -10.0         73               17
# 107     1/5/2012 11:00    -5.6             -10.2         70               22
# 108     1/5/2012 12:00    -4.7              -9.6         69               20
# 109     1/5/2012 13:00    -4.4              -9.7         66               26
# 110     1/5/2012 14:00    -5.1             -10.7         65               22
# ...                ...     ...               ...        ...              ...
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...
